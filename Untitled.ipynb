# %%
import os
import pandas as pd

meta_data = pd.read_csv('data/RFW_Test_Images_Metadata.csv')

# %%
meta_data.shape
# Out:
# (40607, 5)

# %%
absents = []
for index, row in meta_data.iterrows():
    path = os.path.join('/mnt/HDD/DatasetOriginals/RFW/test/data',row['filename'])
    if not os.path.exists(path):
        absents.append(path)

# %%
len(absents)
# Out:
# 30411

# %%
absents[10000:10200]
# Out:
# ['/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.07ch55/m.07ch55_0002.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.03cmpyq/m.03cmpyq_0003.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.03cmpyq/m.03cmpyq_0001.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.03cmpyq/m.03cmpyq_0002.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.0bh7yg4/m.0bh7yg4_0001.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.0bh7yg4/m.0bh7yg4_0002.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.0bh7yg4/m.0bh7yg4_0003.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.03c5v8_/m.03c5v8__0003.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.03c5v8_/m.03c5v8__0001.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.03c5v8_/m.03c5v8__0002.jpg',
#  '/mnt/HDD/DatasetOriginals/RFW/test/data/Caucasian/m.04l0px/m.04l0px_0003.jpg',
# ...
